# %%
from model import *
import importlib
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
p = (Create('A') + Create('B')) * (Transmit('A', 'R_{AB}') + Transmit('B', 'R_{AB}')) * Swap('R_{AB}', ('A', 'B'))
((p + p) * Distill(('A', 'B')))(History([])).draw()
